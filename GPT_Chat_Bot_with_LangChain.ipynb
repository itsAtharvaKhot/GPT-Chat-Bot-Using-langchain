# %%
# %pip install --upgrade -q langchain
# %pip install --upgrade -q langchain-community
# %pip install --upgrade -q openai
# %pip install -q langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.4/720.4 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.3/438.3 kB 8.9 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=False)

from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory, FileChatMessageHistory
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, MessagesPlaceholder

llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=1)

#Adding an additional keyword argument to the ConversationBufferMemory() constructor
history = FileChatMessageHistory('chat_history.json')
memory = ConversationBufferMemory(
    memory_key='chat_history',
    chat_memory=history,
    return_messages=True
)

prompt = ChatPromptTemplate(
    input_variables=["content", "chat_history"],
    messages=[
        SystemMessage(content="You are a chatbot having a conversation with a human."),
        MessagesPlaceholder(variable_name="chat_history"),
        HumanMessagePromptTemplate.from_template("{content}")
    ]
)

chain = LLMChain(
    llm=llm,
    prompt=prompt,
    memory=memory,
    verbose=False
)

while True:
    content = input('Your prompt: ')
    if content.lower() in ['quit', 'exit', 'bye']:
        print('Goodbye!')
        break

    response = chain.invoke({'content': content})
    print(response)
    print('-' * 50)
# Out:
# <ipython-input-2-08b6115a75a3>:14: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(
# <ipython-input-2-08b6115a75a3>:29: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(
# Your prompt: how is the weather today in pune india?
# {'content': 'how is the weather today in pune india?', 'chat_history': [], 'text': "I'm sorry, I don't have real-time information about the weather. You can check the weather in Pune, India by using a weather website or app."}
# --------------------------------------------------
# Your prompt: can you tell me something about german history?
# {'content': 'can you tell me something about german history?', 'chat_history': [HumanMessage(content='how is the weather today in pune india?', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm sorry, I don't have real-time information about the weather. You can check the weather in Pune, India by using a weather website or app.", additional_kwargs={}, response_metadata={})], 'text': 'Certainly! German history is vast and rich, with many notable events and periods. Here are some key points:\n\n1. The Holy Roman Empire: Germany was once a part of the Holy Roman Empire, which was a complex of territories in Central Europe that existed from 962 to 1806.\n\n2. The Reformation: Germany played a significant role in the Protestant Reformation led by Martin Luther in the 16th century, which led to the split of the Catholic Church.\n\n3. The Unification of Germany: In the 19th century, Otto von Bismarck played a key role in unifying the many German states into the German Empire in 1871.\n\n4. World War I and II: Germany was heavily involved in both world wars, leading to significant devastation and ultimately the division of the country into East and West Germany after World War II.\n\n5. Reunification: In 1990, East and West Germany were reunified, leading to the modern Federal Republic of Germany.\n\nThese are just a few highlights from German history, which is incredibly complex and diverse.'}
# --------------------------------------------------
# Your prompt: that was great information thank you for the help
# {'content': 'that was great information thank you for the help', 'chat_history': [HumanMessage(content='how is the weather today in pune india?', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm sorry, I don't have real-time information about the weather. You can check the weather in Pune, India by using a weather website or app.", additional_kwargs={}, response_metadata={}), HumanMessage(content='can you tell me something about german history?', additional_kwargs={}, response_metadata={}), AIMessage(content='Certainly! German history is vast and rich, with many notable events and periods. Here are some key points:\n\n1. The Holy Roman Empire: Germany was once a part of the Holy Roman Empire, which was a complex of territories in Central Europe that existed from 962 to 1806.\n\n2. The Reformation: Germany played a significant role in the Protestant Reformation led by Martin Luther in the 16th century, which led to the split of the Catholic Church.\n\n3. The Unification of Germany: In the 19th century, Otto von Bismarck played a key role in unifying the many German states into the German Empire in 1871.\n\n4. World War I and II: Germany was heavily involved in both world wars, leading to significant devastation and ultimately the division of the country into East and West Germany after World War II.\n\n5. Reunification: In 1990, East and West Germany were reunified, leading to the modern Federal Republic of Germany.\n\nThese are just a few highlights from German history, which is incredibly complex and diverse.', additional_kwargs={}, response_metadata={})], 'text': "You're welcome! If you have any more questions or need further information, feel free to ask. I'm here to help!"}
# --------------------------------------------------
# Your prompt: quit
# Goodbye!

# %%
# The messages property contains the list of messages in order.
print(history.messages)
# Out:
# [HumanMessage(content='how is the weather today in pune india?', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm sorry, I don't have real-time information about the weather. You can check the weather in Pune, India by using a weather website or app.", additional_kwargs={}, response_metadata={}), HumanMessage(content='can you tell me something about german history?', additional_kwargs={}, response_metadata={}), AIMessage(content='Certainly! German history is vast and rich, with many notable events and periods. Here are some key points:\n\n1. The Holy Roman Empire: Germany was once a part of the Holy Roman Empire, which was a complex of territories in Central Europe that existed from 962 to 1806.\n\n2. The Reformation: Germany played a significant role in the Protestant Reformation led by Martin Luther in the 16th century, which led to the split of the Catholic Church.\n\n3. The Unification of Germany: In the 19th century, Otto von Bismarck played a key role in unifying the many German states into the German Empire in 1871.\n\n4. World War I and II: Germany was heavily involved in both world wars, leading to significant devastation and ultimately the division of the country into East and West Germany after World War II.\n\n5. Reunification: In 1990, East and West Germany were reunified, leading to the modern Federal Republic of Germany.\n\nThese are just a few highlights from German history, which is incredibly complex and diverse.', additional_kwargs={}, response_metadata={}), HumanMessage(content='that was great information thank you for the help', additional_kwargs={}, response_metadata={}), AIMessage(content="You're welcome! If you have any more questions or need further information, feel free to ask. I'm here to help!", additional_kwargs={}, response_metadata={})]
